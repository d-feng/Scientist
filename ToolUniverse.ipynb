# %%
## understand ToolUniverse query types
from tooluniverse import ToolUniverse
tooluni = ToolUniverse()
tooluni.load_tools()
tool_name_list, tool_desc_list = tooluni.refresh_tool_name_desc()
import pprint
pprint.pprint(tool_name_list, width=100)
# Out:
# ['get_associated_targets_by_disease_efoId',
#  'get_associated_diseases_phenotypes_by_target_ensemblID',
#  'target_disease_evidence',
#  'get_drug_warnings_by_chemblId',
#  'get_drug_mechanisms_of_action_by_chemblId',
#  'get_associated_drugs_by_disease_efoId',
#  'get_similar_entities_by_disease_efoId',
#  'get_similar_entities_by_drug_chemblId',
#  'get_similar_entities_by_target_ensemblID',
#  'get_associated_phenotypes_by_disease_efoId',
#  'get_drug_withdrawn_blackbox_status_by_chemblId',
#  'search_category_counts_by_query_string',
#  'get_disease_id_description_by_name',
#  'get_drug_id_description_by_name',
#  'get_drug_indications_by_chemblId',
#  'get_target_gene_ontology_by_ensemblID',
#  'get_target_homologues_by_ensemblID',
#  'get_target_safety_profile_by_ensemblID',
#  'get_biological_mouse_models_by_ensemblID',
#  'get_target_genomic_location_by_ensemblID',
#  'get_target_subcellular_locations_by_ensemblID',
#  'get_target_synonyms_by_ensemblID',
# ...

# %%
pprint.pprint(tool_desc_list, width=100)
# Out:
# ['get_associated_targets_by_disease_efoId: Find targets associated with a specific disease or '
#  'phenotype based on efoId.',
#  'get_associated_diseases_phenotypes_by_target_ensemblID: Find diseases or phenotypes associated '
#  'with a specific target using ensemblId.',
#  'target_disease_evidence: Explore evidence that supports a specific target-disease association. '
#  'Input is disease efoId and target ensemblID.',
#  'get_drug_warnings_by_chemblId: Retrieve warnings for a specific drug using ChEMBL ID.',
#  'get_drug_mechanisms_of_action_by_chemblId: Retrieve the mechanisms of action associated with a '
#  'specific drug using chemblId.',
#  'get_associated_drugs_by_disease_efoId: Retrieve known drugs associated with a specific disease '
#  'by disease efoId.',
#  'get_similar_entities_by_disease_efoId: Retrieve similar entities for a given disease efoId using '
#  'a model trained with PubMed.',
# ...
